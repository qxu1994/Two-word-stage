# %%
from wdlen_Thal import wordlenth
from nltk.corpus.reader import CHILDESCorpusReader
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
corpus_root = nltk.data.find( 'corpora/CHILDES/Spanish/')
Thal = CHILDESCorpusReader(corpus_root, 'JacksonThal/.*.xml')
wdlen = wordlenth(Thal)

# %%
df = pd.DataFrame(wdlen).dropna()
df = df[['fname', 'age', 'one','two','three', 'four', 'five']]
df
# Out:
#                       fname   age  one  two  three  four  five
# 0     JacksonThal/10m09.xml  10.0    7    1      0     0     0
# 1     JacksonThal/10m10.xml  10.0    1    0      0     0     0
# 2     JacksonThal/10m11.xml  10.0    2    0      0     0     0
# 3     JacksonThal/10m12.xml  10.0    1    0      0     0     0
# 4     JacksonThal/10m13.xml  10.0    0    0      0     0     0
# 5     JacksonThal/10m14.xml  10.0    1    0      0     0     0
# 6     JacksonThal/10m15.xml  10.0    6    0      0     0     0
# 7     JacksonThal/10m16.xml  10.0    3    1      0     0     0
# 8     JacksonThal/10m17.xml  10.0    6    5      1     0     0
# 9     JacksonThal/10q02.xml  10.0    5    0      0     0     0
# 10    JacksonThal/10q03.xml  10.0    2    0      0     0     0
# 11    JacksonThal/10q04.xml  10.0    2    0      0     0     0
# 12    JacksonThal/10q05.xml  10.0    6    0      0     0     0
# 13    JacksonThal/10q06.xml  10.0    0    1      0     0     0
# 16    JacksonThal/10q18.xml  10.0    8    1      0     0     0
# 17    JacksonThal/10q19.xml  10.0    1    0      0     0     0
# 19   JacksonThal/10sb03.xml  10.0    7    3      0     0     0
# 23   JacksonThal/10sb07.xml  10.0    1    0      0     0     0
# 25   JacksonThal/10sb09.xml  10.0   30    2      1     0     0
# 26   JacksonThal/10sb10.xml  10.0   10    0      0     0     0
# 27   JacksonThal/10sb11.xml  10.0   30    5      1     1     0
# 28   JacksonThal/10sb12.xml  10.0    8    0      0     0     0
# 29   JacksonThal/10sb13.xml  10.0    3    0      0     0     0
# 30   JacksonThal/10sb14.xml  10.0    0    0      0     0     0
# 31   JacksonThal/10sb15.xml  10.0    0    0      0     0     0
# 32    JacksonThal/12m05.xml  12.0    0    0      0     0     0
# 33    JacksonThal/12m06.xml  12.0    2    0      0     0     0
# 34    JacksonThal/12m08.xml  12.0   13    2      0     0     0
# 35    JacksonThal/12m09.xml  12.0   45   17      2     5     0
# 36    JacksonThal/12m10.xml  12.0    4    1      0     0     0
# ..                      ...   ...  ...  ...    ...   ...   ...
# 184   JacksonThal/36q03.xml  36.0   35   26     16    12    18
# 185   JacksonThal/36q05.xml  36.0   46   30     25    15     4
# 186   JacksonThal/36q06.xml  36.0   28   20     25    20    31
# 187   JacksonThal/36q07.xml  36.0   95   28     16     1     1
# 188   JacksonThal/36q08.xml  36.0   47   41     31    16    23
# 189   JacksonThal/36q09.xml  36.0   38   34     28     8     8
# 190   JacksonThal/36q10.xml  36.0   74   32     11    10    19
# 191   JacksonThal/36q11.xml  36.0   21   23     27    21    30
# 192   JacksonThal/36q12.xml  36.0   82   38     13    16    15
# 193  JacksonThal/36qc01.xml  36.0   47   30      8    20    31
# 194  JacksonThal/36qc03.xml  36.0   35   26     16    12    18
# 195  JacksonThal/36qc05.xml  36.0   46   30     25    15     4
# 196  JacksonThal/36qc06.xml  36.0   28   20     25    20    31
# 197  JacksonThal/36qc07.xml  36.0   95   28     16     1     1
# 198  JacksonThal/36qc08.xml  36.0   47   41     31    16    23
# 199  JacksonThal/36qc09.xml  36.0   38   34     28     8     8
# 200  JacksonThal/36qc10.xml  36.0   74   32     11    10    19
# 201  JacksonThal/36qc11.xml  36.0   21   23     27    21    30
# 202  JacksonThal/36qc12.xml  36.0   82   38     13    16    15
# 203  JacksonThal/36sb01.xml  36.0   87   16      0     1     0
# 204  JacksonThal/36sb02.xml  36.0   64   34     12     7     4
# 205  JacksonThal/36sb03.xml  36.0   49   22      7    12    16
# 206  JacksonThal/36sb04.xml  36.0   28   47     15     7    13
# 207  JacksonThal/36sb05.xml  36.0   69    9      1     2     1
# 208  JacksonThal/36sb06.xml  36.0   57   22     13     8    11
# 209  JacksonThal/36sb07.xml  36.0   54   34     28     7     6
# 210  JacksonThal/36sb08.xml  36.0   43   15     19    23    23
# 211  JacksonThal/36sb09.xml  36.0   39   28     11     6    20
# 212  JacksonThal/36sb11.xml  36.0   34   27     20    13    23
# 213  JacksonThal/36sb12.xml  36.0   79   46     21    10    16
#
# [207 rows x 7 columns]

# %%
writer = pd.ExcelWriter('JacksonThal.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %%
plt.figure()
df2 = df.groupby('age').mean().reset_index()
df2.set_index('age').plot.line(rot=0, title='Population', figsize=(15,10), fontsize=12)
plt.show()

# %% [markdown]
# ## percentage with one word utterances

# %%
df_per = df

# %%
df_per['sum'] = df_per.loc[:, 'one':'five'].sum(axis = 1)

# %%
df_per.loc[:, "one":"five"] = df_per.loc[:,"one":"five"].div(df_per["sum"], axis=0)

# %%
df_per = df_per.drop(['sum'], axis = 1)

# %%
df_per.groupby('age').mean()
# Out:
#            one       two     three      four      five
# age
# 10.0  0.883354  0.109024  0.006394  0.001229  0.000000
# 12.0  0.810429  0.153987  0.022787  0.010086  0.002710
# 20.0  0.749194  0.171661  0.056979  0.012535  0.009630
# 28.0  0.540368  0.252081  0.115836  0.048653  0.043061
# 36.0  0.374702  0.232213  0.152246  0.100548  0.140291

# %%
ax = df_per.groupby('age').mean().plot.bar(stacked = True, legend = True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ## percentage without one word utterances

# %%
df_no1 = df.drop('one', axis = 1)

# %%
df_no1['sum'] = df_no1.loc[:, 'two':'five'].sum(axis = 1)

# %%
df_no1.loc[:, "two":"five"] = df_no1.loc[:,"two":"five"].div(df_no1["sum"], axis=0)

# %%
df_no1 = df_no1.drop(['sum'], axis = 1)

# %%
ax = df_no1.groupby('age').mean().plot.bar(stacked = True, legend = True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ## percentage without three and more word utterances

# %%
df_no3 = df.loc[:, 'fname':'two']

# %%
df_no3['sum'] = df_no3.loc[:, 'one':'two'].sum(axis = 1)

# %%
df_no3.loc[:, "one":"two"] = df_no3.loc[:,"one":"two"].div(df_no3["sum"], axis=0)

# %%
df_no3 = df_no3.drop(['sum'], axis = 1)

# %%
ax = df_no3.groupby('age').mean().plot.bar(stacked = True, legend = True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
