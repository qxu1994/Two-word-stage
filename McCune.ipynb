# %%
from try_wdlen import wordlenth
import pandas as pd
import matplotlib.pyplot as plt

# %%
wdlen = wordlenth(r"d:/academy/two_word_stage/corpus/English/McCune/Aurie/*.xml")
# Out:
# parse_mor_element(): element is None <Element '{http://www.talkbank.org/ns/talkbank}w' at 0x000002BA754B3318> um None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b0b054f9a6be> in <module>()
# ----> 1 wdlen = wordlenth(r"d:/academy/two_word_stage/corpus/English/McCune/Aurie/*.xml")
#
# D:\academy\two_word_stage\codes\try_wdlen.py in wordlenth(filepath)
#      36         corpus = list(corpus)
#      37
# ---> 38         wdlen = {'fname': f, 'age': age_transform(metadata), 'one': 0, 'two': 0, 'three': 0, 'four': 0, 'five': 0}
#      39
#      40         for uid, speaker, utterance in corpus:
#
# D:\academy\two_word_stage\codes\try_wdlen.py in age_transform(metadata)
#       8     '''transform the original age into age in months'''
#       9     ageday=0
# ---> 10     for i in metadata:    # get the location of 'Y', 'M', 'D'
#      11         if i == 'Y':
# ...

# %%
df = pd.DataFrame(wdlen)
df = df[['fname', 'age', 'one','two','three', 'four', 'five']]
df
# Out:
#                                                 fname  age  one  two  three  \
# 0   d:/academy/two_word_stage/corpus/English/McCun...    8    0    0      0
# 1   d:/academy/two_word_stage/corpus/English/McCun...    9    0    0      0
# 2   d:/academy/two_word_stage/corpus/English/McCun...   10    0    0      0
# 3   d:/academy/two_word_stage/corpus/English/McCun...   11    0    0      0
# 4   d:/academy/two_word_stage/corpus/English/McCun...   11    0    0      0
# 5   d:/academy/two_word_stage/corpus/English/McCun...   12    0    0      0
# 6   d:/academy/two_word_stage/corpus/English/McCun...   12    0    0      0
# 7   d:/academy/two_word_stage/corpus/English/McCun...   12    0    0      0
# 8   d:/academy/two_word_stage/corpus/English/McCun...   12    0    0      0
# 9   d:/academy/two_word_stage/corpus/English/McCun...   12    0    0      0
# 10  d:/academy/two_word_stage/corpus/English/McCun...   12    6    1      0
# ...
