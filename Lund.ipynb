# %%
from wdlen import wordlenth
from nltk.corpus.reader import CHILDESCorpusReader
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
corpus_root = nltk.data.find( 'corpora/CHILDES/Swedish/')
Davis = CHILDESCorpusReader(corpus_root, 'Lund/.*.xml')
wdlen = wordlenth(Davis)

# %%
df = pd.DataFrame(wdlen).dropna()
df = df[['fname', 'age', 'one','two','three', 'four', 'five']]
df
# Out:
#                         fname   age  one  two  three  four  five
# 244    Lund/Markus/010319.xml  16.0   68   22     10     4     9
# 245    Lund/Markus/010427.xml  17.0   75   13      5     2     0
# 246    Lund/Markus/010610.xml  18.0   66   15     15     7    13
# 247   Lund/Markus/010725a.xml  20.0   89   18      5     6     0
# 248   Lund/Markus/010725b.xml  20.0  327   18      4     3     1
# 249    Lund/Markus/010903.xml  21.0  229    8      4     0     0
# 250    Lund/Markus/010907.xml  21.0  145   47     13     6     4
# 251    Lund/Markus/011014.xml  22.0  201   85     27     8     1
# 252    Lund/Markus/011025.xml  23.0   67   44     18     4     2
# 253    Lund/Markus/011100.xml  23.0   75   62     40    19    10
# 254    Lund/Markus/011112.xml  23.0   84   62     39    32    24
# 255    Lund/Markus/011125.xml  24.0   47   37     51    31    25
# 256    Lund/Markus/020009.xml  24.0   30   37     70    42    50
# 257    Lund/Markus/020016.xml  25.0   26   34     56    50    42
# 258    Lund/Markus/020025.xml  25.0   64   34     57    49    43
# 259   Lund/Markus/020205a.xml  26.0   65   54     58    50    85
# 260   Lund/Markus/020205b.xml  26.0   37   17     18    14    32
# 261    Lund/Markus/020210.xml  26.0   53   44     65    50    76
# 262    Lund/Markus/020217.xml  27.0   38   29     28    38    52
# 263    Lund/Markus/020309.xml  27.0   37   24     34    27    72
# 264    Lund/Markus/020328.xml  28.0   67   34     58    78   115
# 265    Lund/Markus/020409.xml  28.0   50   19     39    36    42
# 266    Lund/Markus/020418.xml  29.0   67   49     74    56    76
# 267    Lund/Markus/020620.xml  31.0   82   36     55    35   124
# 268    Lund/Markus/020724.xml  32.0   67   25     17    34    49
# 269    Lund/Markus/020802.xml  32.0   46   19     29    28    71
# 270    Lund/Markus/020808.xml  32.0   37    7     10    18    54
# 271    Lund/Markus/020929.xml  34.0   28   27     22    53   149
# 272  Lund/Markus/mar15_19.xml  16.0   68   22     10     4     9
# 273  Lund/Markus/mar16_27.xml  17.0   75   13      5     2     0
# 274  Lund/Markus/mar18_10.xml  18.0   66   15     15     7    13
# 275  Lund/Markus/mar19_25.xml  20.0   89   18      5     6     0
# 276  Lund/Markus/mar20_05.xml  20.0  327   18      4     3     1
# 277  Lund/Markus/mar21_03.xml  21.0  229    8      4     0     0
# 278  Lund/Markus/mar21_07.xml  21.0  145   47     13     6     4
# 279  Lund/Markus/mar22_14.xml  22.0  201   85     27     8     1
# 280  Lund/Markus/mar22_25.xml  23.0   67   44     18     4     2
# 281  Lund/Markus/mar23_00.xml  23.0   75   62     40    19    10
# 282  Lund/Markus/mar23_12.xml  23.0   84   62     39    32    24
# 283  Lund/Markus/mar23_25.xml  24.0   47   37     51    31    25
# 284  Lund/Markus/mar24_09.xml  24.0   30   37     70    42    50
# 285  Lund/Markus/mar24_16.xml  25.0   26   34     56    50    42
# 286  Lund/Markus/mar24_25.xml  25.0   64   34     57    49    43
# 287  Lund/Markus/mar26_05.xml  26.0   65   54     58    50    85
# 288  Lund/Markus/mar26_10.xml  26.0   53   44     65    50    76
# 289  Lund/Markus/mar26_17.xml  27.0   38   29     28    38    52
# 290  Lund/Markus/mar27_09.xml  27.0   37   24     34    27    72
# 291  Lund/Markus/mar27_28.xml  28.0   67   34     58    78   115
# 292  Lund/Markus/mar28_09.xml  28.0   50   19     39    36    42
# 293  Lund/Markus/mar28_18.xml  29.0   67   49     74    56    76
# 294  Lund/Markus/mar30_20.xml  31.0   82   36     55    35   124
# 295  Lund/Markus/mar30_25.xml  26.0   37   17     18    14    32
# 296  Lund/Markus/mar31_24.xml  32.0   67   25     17    34    49
# 297  Lund/Markus/mar32_02.xml  32.0   46   19     29    28    71
# 298  Lund/Markus/mar32_08.xml  32.0   37    7     10    18    54
# 299  Lund/Markus/mar33_29.xml  34.0   28   27     22    53   149

# %%
plt.figure()
df2 = df.groupby('age').mean().reset_index()
df2.set_index('age').plot.line(rot=0, title='Population', figsize=(15,10), fontsize=12)
plt.show()
