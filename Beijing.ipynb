# %%
from wdlen import wordlenth
from nltk.corpus.reader import CHILDESCorpusReader
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
corpus_root = nltk.data.find( 'corpora/CHILDES/Chinese/')
Beijing = CHILDESCorpusReader(corpus_root, 'Beijing/.*.xml')
wdlen = wordlenth(Beijing)

# %%
df = pd.DataFrame(wdlen).dropna()
df = df[['fname', 'age', 'one','two','three', 'four', 'five']]
df
# Out:
#                     fname   age  one  two  three  four  five
# 0   Beijing/bb/011012.xml  22.0  277  113     50    30    36
# 2   Beijing/bb/020000.xml  24.0  169  169    135    67    71
# 3   Beijing/bb/020100.xml  25.0   97   79     75    37    19
# 4   Beijing/bb/020207.xml  26.0  215  213    190   122   110
# 5      Beijing/bb/bb1.xml  22.0  277  113     50    30    36
# 7      Beijing/bb/bb3.xml  24.0  169  169    135    67    71
# 8      Beijing/bb/bb4.xml  25.0   97   79     75    37    19
# 9      Beijing/bb/bb5.xml  26.0  215  213    190   122   110
# 10  Beijing/cx/010925.xml  22.0  230  141     39    24    24
# 11  Beijing/cx/011015.xml  22.0  184  135     55    23    10
# 12  Beijing/cx/011100.xml  23.0  197  120     77    36    12
# 13  Beijing/cx/020015.xml  24.0  341  163     92    35    16
# 14  Beijing/cx/020118.xml  26.0  300  158     65    15    13
# 15     Beijing/cx/cx1.xml  22.0  230  141     39    24    24
# 16     Beijing/cx/cx2.xml  22.0  184  135     55    23    10
# 17     Beijing/cx/cx3.xml  23.0  197  120     77    36    12
# 18     Beijing/cx/cx4.xml  24.0  341  163     92    35    16
# 19     Beijing/cx/cx5.xml  26.0  300  158     65    15    13
# 20  Beijing/hy/010910.xml  21.0  421  337    128    79    45
# 21  Beijing/hy/010930.xml  22.0  167  212    138    88    67
# 22  Beijing/hy/011020.xml  23.0  351  340    166    67    31
# 23  Beijing/hy/011115.xml  23.0  181  198    102    34    20
# 24  Beijing/hy/020118.xml  26.0  105  141    128    80    51
# 25     Beijing/hy/hy1.xml  21.0  421  337    128    79    45
# 26     Beijing/hy/hy2.xml  22.0  167  212    138    88    67
# 27     Beijing/hy/hy3.xml  23.0  351  340    166    67    31
# 28     Beijing/hy/hy4.xml  23.0  181  198    102    34    20
# 29     Beijing/hy/hy6.xml  26.0  105  141    128    80    51
# 30  Beijing/lc/010921.xml  22.0  423  230     61    17     4
# 31  Beijing/lc/011021.xml  23.0  282  167     96    27    18
# ..                    ...   ...  ...  ...    ...   ...   ...
# 70  Beijing/ww/011028.xml  23.0  128   84     63    35    39
# 71  Beijing/ww/011130.xml  24.0  129   99    101    75    73
# 72  Beijing/ww/020005.xml  24.0   61   82     79    61    80
# 73  Beijing/ww/020115.xml  25.0   78   83     61    45    38
# 74  Beijing/ww/020302.xml  27.0  150   95     60    68    49
# 75     Beijing/ww/ww1.xml  23.0  128   84     63    35    39
# 76     Beijing/ww/ww2.xml  24.0  129   99    101    75    73
# 77     Beijing/ww/ww3.xml  24.0   61   82     79    61    80
# 78     Beijing/ww/ww4.xml  25.0   78   83     61    45    38
# 79     Beijing/ww/ww6.xml  27.0  150   95     60    68    49
# 80  Beijing/wx/010927.xml  22.0   98  104     55    28    27
# 81  Beijing/wx/011100.xml  23.0  165  136     87    72    98
# 82  Beijing/wx/020000.xml  24.0  102  160    121    61   101
# 83  Beijing/wx/020100.xml  25.0  129  140    116    81   161
# 84  Beijing/wx/020120.xml  26.0  280  182    139   103   185
# 85     Beijing/wx/wx1.xml  22.0   98  104     55    28    27
# 86     Beijing/wx/wx2.xml  23.0  165  136     87    72    98
# 87     Beijing/wx/wx3.xml  24.0  102  160    121    61   101
# 88     Beijing/wx/wx4.xml  25.0  129  140    116    81   161
# 89     Beijing/wx/wx5.xml  26.0  280  182    139   103   185
# 90  Beijing/yy/011020.xml  23.0   75  119     66    36    15
# 91  Beijing/yy/011130.xml  24.0  168   90     54    42    34
# 92  Beijing/yy/020010.xml  24.0  151   72     49    32    38
# 93  Beijing/yy/020105.xml  25.0  263   90     70    71    95
# 94  Beijing/yy/020218.xml  27.0  229   82     77    80   122
# 95     Beijing/yy/yy1.xml  23.0   75  119     66    36    15
# 96     Beijing/yy/yy2.xml  24.0  168   90     54    42    34
# 97     Beijing/yy/yy3.xml  24.0  151   72     49    32    38
# 98     Beijing/yy/yy4.xml  25.0  263   90     70    71    95
# 99     Beijing/yy/yy6.xml  27.0  229   82     77    80   122
#
# [98 rows x 7 columns]

# %%
plt.figure()
df2 = df.groupby('age').mean().reset_index()
df2.set_index('age').plot.line(rot=0, title='Population', figsize=(15,10), fontsize=12)
plt.show()
